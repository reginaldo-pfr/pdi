# %%
import cv2 #OpenCV
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../pdi/figs/lena_color_256.tif')

# %%
img
# Out:
# array([[[125, 137, 226],
#         [130, 136, 223],
#         [118, 133, 226],
#         ...,
#         [127, 145, 230],
#         [122, 148, 232],
#         [100, 114, 210]],
#
#        [[125, 137, 226],
#         [130, 136, 223],
#         [118, 133, 226],
#         ...,
#         [127, 145, 230],
#         [122, 148, 232],
#         [100, 114, 210]],
#
#        [[124, 138, 226],
#         [121, 133, 223],
#         [117, 134, 226],
#         ...,
#         [118, 133, 222],
#         [108, 125, 217],
#         [ 90,  87, 182]],
#
#        ...,
#
#        [[ 61,  28,  90],
#         [ 61,  28,  91],
#         [ 63,  29,  97],
#         ...,
#         [ 71,  53, 140],
#         [ 73,  62, 158],
#         [ 74,  59, 161]],
#
#        [[ 60,  20,  85],
#         [ 59,  25,  91],
#         [ 62,  26,  94],
#         ...,
#         [ 82,  64, 153],
#         [ 81,  69, 172],
#         [ 78,  65, 170]],
#
#        [[ 57,  22,  82],
#         [ 62,  30,  94],
#         [ 61,  25,  95],
#         ...,
#         [ 84,  71, 167],
#         [ 78,  68, 178],
#         [ 81,  72, 183]]], dtype=uint8)

# %%
img[:,:,0]
# Out:
# array([[125, 130, 118, ..., 127, 122, 100],
#        [125, 130, 118, ..., 127, 122, 100],
#        [124, 121, 117, ..., 118, 108,  90],
#        ...,
#        [ 61,  61,  63, ...,  71,  73,  74],
#        [ 60,  59,  62, ...,  82,  81,  78],
#        [ 57,  62,  61, ...,  84,  78,  81]], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ### Pela OpenCV

# %%
cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb[:,:,0])
plt.show()

# %%
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb[:,:,1])
plt.show()

# %%
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb[:,:,2])
plt.show()

# %%
img = cv2.imread('../pdi/figs/lena_color_256.tif', cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[162, 161, 159, ..., 168, 170, 141],
#        [162, 161, 159, ..., 168, 170, 141],
#        [163, 159, 160, ..., 158, 151, 116],
#        ...,
#        [ 50,  51,  53, ...,  81,  92,  91],
#        [ 44,  49,  50, ...,  93, 101,  98],
#        [ 44,  53,  50, ..., 101, 102, 106]], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256)

# %%
plt.imshow(img)
plt.imshow(img, 'gray')
plt.show()

# %%
plt.imshow(im_rgb)

# %%
cv2.imwrite('lena_output.png', img)
# Out:
# True
